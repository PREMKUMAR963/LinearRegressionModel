# %%
import warnings
warnings.simplefilter("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=pd.read_excel("Cgpa_VS_ProabilityToAdmit.xlsx")

# %%
dataset
# Out:
#      Serial No.  CGPA  ProabilityToAdmit
# 0             1  8.15               0.67
# 1             2  7.95               0.67
# 2             3  7.88               0.59
# 3             4  8.12               0.62
# 4             5  8.18               0.65
# ..          ...   ...                ...
# 443         444  9.16               0.87
# 444         445  9.25               0.92
# 445         446  9.08               0.91
# 446         447  9.67               0.93
# 447         448  8.97               0.84
#
# [448 rows x 3 columns]

# %%
dataset.shape
# Out:
# (448, 3)

# %%
dataset.head()
# Out:
#    Serial No.  CGPA  ProabilityToAdmit
# 0           1  8.15               0.67
# 1           2  7.95               0.67
# 2           3  7.88               0.59
# 3           4  8.12               0.62
# 4           5  8.18               0.65

# %% [markdown]
# # Slicing data set - Removing the columns

# %%
dataset=dataset.drop(['Serial No.'],axis=1)
dataset
# Out:
#      CGPA  ProabilityToAdmit
# 0    8.15               0.67
# 1    7.95               0.67
# 2    7.88               0.59
# 3    8.12               0.62
# 4    8.18               0.65
# ..    ...                ...
# 443  9.16               0.87
# 444  9.25               0.92
# 445  9.08               0.91
# 446  9.67               0.93
# 447  8.97               0.84
#
# [448 rows x 2 columns]

# %%
y=dataset.iloc[:,-1].values.reshape(-1,1)
y.shape
# Out:
# (448, 1)

# %%
y
# Out:
# array([[0.67],
#        [0.67],
#        [0.59],
#        [0.62],
#        [0.65],
#        [0.71],
#        [0.79],
#        [0.8 ],
#        [0.78],
#        [0.83],
#        [0.71],
#        [0.73],
#        [0.7 ],
#        [0.68],
#        [0.79],
#        [0.76],
#        [0.65],
#        [0.67],
#        [0.54],
#        [0.53],
#        [0.62],
#        [0.68],
#        [0.87],
#        [0.96],
#        [0.93],
#        [0.73],
#        [0.84],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
x=dataset.iloc[:,0].values.reshape(-1,1)
x
# Out:
# array([[8.15],
#        [7.95],
#        [7.88],
#        [8.12],
#        [8.18],
#        [8.49],
#        [8.96],
#        [9.01],
#        [8.48],
#        [8.77],
#        [7.92],
#        [7.89],
#        [8.34],
#        [8.37],
#        [9.14],
#        [8.62],
#        [8.5 ],
#        [8.12],
#        [7.81],
#        [7.69],
#        [8.22],
#        [8.45],
#        [9.02],
#        [9.87],
#        [9.56],
#        [8.43],
#        [9.04],
#        [7.5 ],
#        [7.2 ],
#        [7.3 ],
#        [8.1 ],
#        [8.3 ],
#        [9.4 ],
#        [9.6 ],
#        [9.8 ],
#        [9.2 ],
#        [8.4 ],
#        [7.8 ],
#        [7.5 ],
#        [7.7 ],
#        [8.  ],
#        [8.2 ],
#        [8.5 ],
#        [9.1 ],
#        [9.4 ],
#        [9.1 ],
#        [9.3 ],
#        [9.7 ],
#        [8.85],
#        [8.4 ],
#        [8.3 ],
#        [7.9 ],
#        [8.  ],
#        [8.1 ],
#        [8.  ],
#        [7.7 ],
#        [7.4 ],
#        [7.6 ],
# ...

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=0)

# %%
x_train.shape
# Out:
# (358, 1)

# %%
x_test.shape
# Out:
# (90, 1)

# %%
y_train.shape
# Out:
# (358, 1)

# %%
y_test.shape
# Out:
# (90, 1)

# %% [markdown]
# # Import the function for Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predict chances of admit using test dataset

# %%
y_pred = lm.predict(x_test)

# %%
y_pred
# Out:
# array([[0.70077029],
#        [0.60305134],
#        [0.5302819 ],
#        [0.65295038],
#        [0.73819457],
#        [0.86917955],
#        [0.67374164],
#        [0.646713  ],
#        [0.57394356],
#        [0.75274846],
#        [0.5302819 ],
#        [0.65710863],
#        [0.70700767],
#        [0.81304313],
#        [0.44711683],
#        [0.69661204],
#        [0.45335421],
#        [0.5926557 ],
#        [0.58641832],
#        [0.71532418],
#        [0.79017274],
#        [0.65918776],
#        [0.53651928],
#        [0.71948243],
#        [0.71324505],
#        [0.6238426 ],
#        [0.46582897],
#        [0.75898584],
#        [0.65087125],
#        [0.97313588],
#        [0.7402737 ],
#        [0.53236103],
#        [0.64047562],
#        [0.5614688 ],
#        [0.67166252],
#        [0.84630916],
#        [0.83591352],
#        [0.82343876],
#        [0.67374164],
#        [0.7174033 ],
#        [0.57394356],
#        [0.69037466],
#        [0.59473483],
# ...

# %% [markdown]
# # Check Using a Regression Line

# %%
plt.scatter(x,y,color='blue')
plt.plot(x_test,y_pred,color='red')
